# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:25, 1.25MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
print(int_words[0:10])
# Out:
# [5239, 3082, 11, 5, 194, 1, 3135, 45, 58, 155]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)
    
    return

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), 1, -1))
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6338 0.5793 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6013 0.4715 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4857 0.4906 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5831 0.5307 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5431 0.5120 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5036 0.5165 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5469 0.6426 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4751 0.5086 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4791 0.5004 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4377 0.5316 sec/batch
# Nearest to over: memoryless, posed, barghouti, otherwise, reeves, begining, apolitical, donaldson,
# Nearest to this: lauper, sapphic, marat, redesigns, kokomo, abner, dinneen, injective,
# Nearest to see: disruptive, rsfsr, learning, weeks, patricia, vandal, livres, vedder,
# Nearest to after: vulnerable, amiable, acculturation, testimonials, fearful, medal, creations, dub,
# Nearest to an: stol, fruiting, caveat, touted, balk, arterial, agree, heroin,
# Nearest to which: silencing, narrows, vogel, wim, engelbert, culhwch, nitrox, entitled,
# Nearest to been: hin, paps, soninke, encirclement, extraordinarily, erythromycin, tactics, landi,
# Nearest to used: photocopies, beetles, jaw, reclaimed, alphonso, pac, reconfiguration, lyon,
# Nearest to heavy: romero, theodosian, drifted, warrior, wilhelmshaven, urge, liam, imo,
# Nearest to nobel: theory, omniglot, lumbar, hales, pyrite, subscripts, ringed, tolkien,
# Nearest to award: facile, zinoviev, fallen, keltoi, wong, philipp, commonwealth, abundantly,
# Nearest to magazine: limerick, addams, takahashi, bells, belatedly, madrid, jawaharlal, cofactor,
# Nearest to construction: rterbuch, explicated, maroger, subscribe, grim, duet, insane, disfellowshipped,
# Nearest to experience: numeration, dual, fibrous, ejective, combines, jtf, disulfide, ncaa,
# Nearest to hit: maldivians, rubbish, slim, india, darryl, dtmf, rap, codon,
# Nearest to marriage: headstone, baal, overline, striving, feyenoord, speculate, overgrazing, everything,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5020 0.5101 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3793 0.4964 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3072 0.4982 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2053 0.5401 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1611 0.5928 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1518 0.5147 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1361 0.4945 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0414 0.4682 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0048 0.4761 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9880 0.4695 sec/batch
# Nearest to over: posed, otherwise, structure, down, memoryless, integrated, apolitical, common,
# Nearest to this: understanding, standard, marat, variable, accomplished, national, than, policies,
# Nearest to see: learning, disruptive, weeks, today, patricia, governors, eliminated, chance,
# Nearest to after: vulnerable, medal, fearful, creations, late, acculturation, project, accept,
# Nearest to an: agree, stol, bureau, touted, fruiting, heroin, caveat, thrills,
# Nearest to which: silencing, narrows, entitled, popular, elaborate, presidency, determines, should,
# Nearest to been: hin, soninke, encirclement, planned, tactics, paps, accorded, existed,
# Nearest to used: photocopies, beetles, jaw, hollywood, reclaimed, allowed, lyon, critique,
# Nearest to heavy: that, drifted, romero, warrior, theodosian, here, current, sent,
# Nearest to nobel: theory, tolkien, lumbar, occurred, hales, structuring, obp, subscripts,
# Nearest to award: facile, fallen, commonwealth, zinoviev, philipp, go, centimeters, lakes,
# Nearest to magazine: addams, madrid, limerick, sufficient, takahashi, bells, encyclopedias, belatedly,
# Nearest to construction: december, insane, legally, rterbuch, across, maroger, phospholipid, serial,
# Nearest to experience: numeration, dual, combines, as, ncaa, benelux, decade, disulfide,
# Nearest to hit: india, slim, rap, rubbish, darryl, brightness, melt, coma,
# Nearest to marriage: overline, striving, baal, headstone, everything, series, speculate, feyenoord,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9603 0.4957 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8603 0.5180 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8695 0.6342 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8519 0.4846 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8148 0.4684 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8013 0.4701 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7751 0.4896 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8193 0.5349 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7870 0.4978 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7862 0.4680 sec/batch
# Nearest to over: posed, otherwise, restoration, structure, apolitical, memoryless, reeves, barghouti,
# Nearest to this: standard, understanding, variable, lauper, accomplished, sapphic, marat, discourage,
# Nearest to see: disruptive, learning, weeks, vandal, patricia, rsfsr, today, sacrifice,
# Nearest to after: vulnerable, medal, fearful, acculturation, creations, testimonials, late, amiable,
# Nearest to an: agree, stol, fruiting, arterial, caveat, bureau, heroin, bros,
# Nearest to which: silencing, narrows, determines, elaborate, insulting, entitled, potassium, secrets,
# Nearest to been: hin, soninke, extraordinarily, planned, encirclement, repairs, paps, insignificant,
# Nearest to used: photocopies, hollywood, beetles, nutrition, jaw, replete, reclaimed, lyon,
# Nearest to heavy: drifted, that, warrior, romero, theodosian, boniface, urge, sent,
# Nearest to nobel: theory, tolkien, occurred, amazed, hales, lumbar, obp, structuring,
# Nearest to award: facile, fallen, philipp, awarded, centimeters, commonwealth, melt, wong,
# Nearest to magazine: addams, madrid, bells, limerick, belatedly, cellulose, takahashi, modulation,
# Nearest to construction: subscribe, insane, rterbuch, boycotted, december, pbs, grim, acted,
# Nearest to experience: numeration, dual, combines, ncaa, benelux, as, fibrous, irrational,
# Nearest to hit: slim, india, rap, rubbish, darryl, melt, faithful, brightness,
# Nearest to marriage: striving, speculate, overline, stephen, baal, series, everything, headstone,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7809 0.4780 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7591 0.5162 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.6966 0.5638 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7110 0.5693 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7171 0.6014 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6945 0.5472 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7041 0.5510 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7354 0.5439 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7085 0.5455 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6531 0.5509 sec/batch
# Nearest to over: posed, otherwise, restoration, structure, apolitical, reeves, donaldson, memoryless,
# Nearest to this: understanding, standard, sapphic, lauper, variable, discourage, injective, italic,
# Nearest to see: learning, disruptive, vandal, weeks, patricia, rsfsr, dagger, soho,
# Nearest to after: medal, vulnerable, amiable, fearful, late, acculturation, creations, glover,
# Nearest to an: stol, caveat, fruiting, arterial, agree, bros, divest, bureau,
# Nearest to which: narrows, silencing, determines, insulting, vogel, residual, secrets, entitled,
# Nearest to been: hin, soninke, extraordinarily, encirclement, planned, paps, hobsbawm, repairs,
# Nearest to used: photocopies, beetles, nutrition, replete, jaw, users, taboo, lyon,
# Nearest to heavy: drifted, romero, smash, that, warrior, theodosian, boniface, sent,
# Nearest to nobel: tolkien, economist, theory, hales, substantiate, manchus, occurred, utilities,
# Nearest to award: facile, awarded, philipp, zinoviev, fallen, kate, centimeters, wong,
# Nearest to magazine: addams, belatedly, limerick, madrid, jawaharlal, bells, cellulose, reconquering,
# Nearest to construction: subscribe, rterbuch, insane, explicated, boycotted, december, duet, letterboxing,
# Nearest to experience: numeration, dual, combines, benelux, fibrous, as, ncaa, personalized,
# Nearest to hit: slim, rap, india, darryl, rubbish, melt, sofia, reintroduced,
# Nearest to marriage: baal, headstone, speculate, quartets, stephen, striving, overline, series,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6767 0.5766 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6856 0.5612 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6301 0.5475 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6213 0.5636 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6308 0.5523 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6483 0.5446 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5791 0.4139 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5566 0.5487 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5292 0.5455 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4989 0.6627 sec/batch
# Nearest to over: posed, otherwise, restoration, dictators, donaldson, evidentiary, barghouti, whisky,
# Nearest to this: understanding, without, sapphic, variable, standard, parsed, italic, injective,
# Nearest to see: learning, disruptive, vandal, rsfsr, soho, weeks, today, vedder,
# Nearest to after: medal, amiable, vulnerable, fearful, acculturation, testimonials, mismanagement, late,
# Nearest to an: arterial, stol, caveat, fruiting, divest, bros, heroin, barton,
# Nearest to which: narrows, silencing, insulting, vogel, determines, residual, secrets, standards,
# Nearest to been: hin, paps, encirclement, extraordinarily, account, erythromycin, planned, soninke,
# Nearest to used: photocopies, beetles, users, jaw, nutrition, adaptable, replete, allowed,
# Nearest to heavy: smash, theodosian, drifted, romero, that, warrior, boniface, ailes,
# Nearest to nobel: economist, tolkien, substantiate, eight, comedian, laureate, hales, manchus,
# Nearest to award: facile, awarded, philipp, kate, zinoviev, wong, eurosceptics, trader,
# Nearest to magazine: addams, belatedly, jawaharlal, limerick, bells, madrid, film, cellulose,
# Nearest to construction: subscribe, rterbuch, explicated, letterboxing, december, monopolistic, boycotted, across,
# Nearest to experience: numeration, dual, as, combines, fibrous, benelux, ncaa, disulfide,
# Nearest to hit: slim, rap, darryl, india, rubbish, melt, sofia, maldivians,
# Nearest to marriage: speculate, baal, quartets, headstone, stephen, southwards, graced, overline,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4903 0.7113 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5074 0.5676 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4753 0.6524 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5261 0.6593 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4990 0.6809 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4816 0.6437 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4505 0.6427 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4169 0.6356 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4231 0.6412 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4293 0.6425 sec/batch
# Nearest to over: posed, dictators, otherwise, apolitical, donaldson, whisky, restoration, tickets,
# Nearest to this: understanding, variable, injective, without, sapphic, parsed, standard, realization,
# Nearest to see: learning, disruptive, vandal, rsfsr, soho, corum, vedder, dagger,
# Nearest to after: vulnerable, medal, acculturation, fearful, amiable, watling, mismanagement, testimonials,
# Nearest to an: arterial, caveat, fruiting, stol, divest, autonomously, heroin, agree,
# Nearest to which: narrows, silencing, determines, vogel, insulting, midgard, motivation, residual,
# Nearest to been: hin, encirclement, paps, account, erythromycin, extraordinarily, survives, hobsbawm,
# Nearest to used: photocopies, beetles, computer, users, nutrition, jaw, insert, taboo,
# Nearest to heavy: smash, theodosian, drifted, warrior, freshmen, ailes, romero, cannae,
# Nearest to nobel: economist, tolkien, substantiate, laureate, hales, comedian, manchus, obp,
# Nearest to award: awarded, facile, wong, kate, zinoviev, philipp, trader, eurosceptics,
# Nearest to magazine: belatedly, addams, jawaharlal, film, cellulose, limerick, paged, squatters,
# Nearest to construction: subscribe, december, letterboxing, explicated, rterbuch, across, unsustainable, boycotted,
# Nearest to experience: numeration, as, combines, fibrous, dual, benelux, personalized, irrational,
# Nearest to hit: slim, rap, darryl, rubbish, disappointment, aces, india, sofia,
# Nearest to marriage: speculate, baal, quartets, southwards, headstone, stephen, graced, everything,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4411 0.6523 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4000 0.6961 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4469 0.7669 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3846 0.5202 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4161 0.4672 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4728 0.4781 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4108 0.4721 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3779 0.4691 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4208 0.4690 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3790 0.4731 sec/batch
# Nearest to over: posed, otherwise, dictators, barghouti, whisky, donaldson, tickets, restoration,
# Nearest to this: without, understanding, variable, injective, sapphic, parsed, realization, divisible,
# Nearest to see: learning, rsfsr, disruptive, vandal, corum, dagger, soho, souk,
# Nearest to after: vulnerable, testimonials, medal, acculturation, fearful, amiable, skyway, mismanagement,
# Nearest to an: arterial, divest, fruiting, stol, caveat, heroin, autonomously, thrills,
# Nearest to which: narrows, silencing, determines, usually, nitrox, athaliah, residual, midgard,
# Nearest to been: hin, encirclement, paps, glorifying, account, horrible, existed, extraordinarily,
# Nearest to used: photocopies, beetles, computer, users, insert, replete, nutrition, taboo,
# Nearest to heavy: smash, theodosian, drifted, freshmen, warrior, ailes, eating, attenuated,
# Nearest to nobel: economist, laureate, substantiate, hales, tolkien, comedian, theory, pacifist,
# Nearest to award: awarded, facile, fiction, wong, zinoviev, jr, kate, pitched,
# Nearest to magazine: film, addams, belatedly, jawaharlal, promotional, paged, squatters, limerick,
# Nearest to construction: subscribe, explicated, december, letterboxing, across, unsustainable, rterbuch, monopolistic,
# Nearest to experience: numeration, as, fibrous, combines, dual, irrational, benelux, mores,
# Nearest to hit: rap, slim, darryl, disappointment, rubbish, aces, sofia, mike,
# Nearest to marriage: baal, speculate, quartets, southwards, stephen, graced, protectionist, headstone,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3945 0.4825 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3874 0.4704 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3790 0.4738 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3696 0.4722 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3727 0.4728 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3520 0.4724 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3797 0.6385 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3255 0.6099 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3332 0.5517 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3326 0.4692 sec/batch
# Nearest to over: posed, otherwise, whisky, dictators, barghouti, restoration, romani, toulon,
# Nearest to this: without, variable, injective, divisible, sapphic, understanding, approx, parsed,
# Nearest to see: learning, disruptive, vandal, rsfsr, souk, dagger, corum, brandeis,
# Nearest to after: vulnerable, testimonials, fearful, medal, skyway, amiable, acculturation, playfair,
# Nearest to an: divest, caveat, fruiting, arterial, stol, agree, heroin, varitek,
# Nearest to which: narrows, silencing, midgard, athaliah, determines, usually, residual, beholder,
# Nearest to been: encirclement, paps, extraordinarily, existed, hin, glorifying, erythromycin, soninke,
# Nearest to used: photocopies, beetles, computer, users, insert, lexicon, jaw, adaptable,
# Nearest to heavy: smash, theodosian, freshmen, ailes, rougher, types, attenuated, cannae,
# Nearest to nobel: economist, laureate, theory, substantiate, pacifist, hales, tolkien, randi,
# Nearest to award: awarded, fiction, facile, wong, nbc, jr, kate, zinoviev,
# Nearest to magazine: film, promotional, belatedly, jawaharlal, addams, paged, cellulose, bowie,
# Nearest to construction: december, subscribe, letterboxing, across, unsustainable, explicated, roasting, monopolistic,
# Nearest to experience: numeration, as, combines, dual, fibrous, benelux, mores, irrational,
# Nearest to hit: rap, slim, darryl, mike, disappointment, aces, rubbish, sofia,
# Nearest to marriage: speculate, baal, quartets, graced, stephen, headstone, southwards, swore,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3613 0.4797 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3043 0.4810 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3904 0.4746 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3855 0.4699 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4325 0.4754 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2957 0.5084 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2938 0.6447 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3751 0.6648 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2252 0.6523 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2971 0.6574 sec/batch
# Nearest to over: posed, otherwise, whisky, dictators, evidentiary, barghouti, restoration, male,
# Nearest to this: without, variable, injective, divisible, antients, sapphic, weert, approx,
# Nearest to see: learning, rsfsr, vandal, souk, disruptive, corum, dictionary, brandeis,
# Nearest to after: vulnerable, fearful, testimonials, amiable, medal, skyway, mismanagement, opold,
# Nearest to an: divest, caveat, arterial, fruiting, stol, heroin, genealogical, exists,
# Nearest to which: narrows, athaliah, beholder, as, midgard, populace, determines, usually,
# Nearest to been: paps, horrible, encirclement, existed, hobsbawm, glorifying, erythromycin, hin,
# Nearest to used: photocopies, beetles, lexicon, computer, insert, nutrition, users, replete,
# Nearest to heavy: smash, theodosian, ailes, rougher, freshmen, cannae, facilities, attenuated,
# Nearest to nobel: economist, laureate, theory, pacifist, substantiate, karl, beccaria, hales,
# Nearest to award: awarded, fiction, nbc, wong, tv, kate, jr, pitched,
# Nearest to magazine: film, promotional, jawaharlal, addams, belatedly, paged, billingsley, squatters,
# Nearest to construction: letterboxing, december, across, roasting, subscribe, monopolistic, unsustainable, explicated,
# Nearest to experience: numeration, combines, as, fibrous, dual, denaturation, mores, irrational,
# Nearest to hit: rap, slim, darryl, mike, aces, disappointment, maldivians, mcg,
# Nearest to marriage: baal, speculate, quartets, headstone, everything, swore, freud, protectionist,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3238 0.6539 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3035 0.6632 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3273 0.3677 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2381 0.7024 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2503 0.6296 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2398 0.6316 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2132 0.6403 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2209 0.6288 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2097 0.6305 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1757 0.6350 sec/batch
# Nearest to over: otherwise, posed, dictators, whisky, evidentiary, barghouti, restoration, doers,
# Nearest to this: without, grammarians, divisible, weert, injective, antients, parsed, watchful,
# Nearest to see: learning, rsfsr, vandal, corum, souk, dictionary, periodicals, disruptive,
# Nearest to after: vulnerable, testimonials, medal, fearful, amiable, skyway, mismanagement, kills,
# Nearest to an: divest, caveat, arterial, stol, fruiting, heroin, genealogical, steered,
# Nearest to which: narrows, beholder, midgard, athaliah, residual, ailes, silencing, as,
# Nearest to been: hobsbawm, paps, erythromycin, encirclement, horrible, existed, extraordinarily, repairs,
# Nearest to used: photocopies, beetles, lexicon, nutrition, computer, animation, ingots, users,
# Nearest to heavy: smash, types, attenuated, wheeled, rougher, facilities, ailes, freshmen,
# Nearest to nobel: economist, laureate, theory, pacifist, substantiate, karl, beccaria, hales,
# Nearest to award: awarded, fiction, nbc, wong, awards, pitched, fuerzas, eurosceptics,
# Nearest to magazine: promotional, film, jawaharlal, addams, belatedly, squatters, paged, billingsley,
# Nearest to construction: letterboxing, december, subscribe, across, monopolistic, roasting, explicated, unsustainable,
# Nearest to experience: numeration, combines, denaturation, as, fibrous, dual, disdain, mores,
# Nearest to hit: rap, slim, darryl, mike, disappointment, aces, charts, maldivians,
# Nearest to marriage: baal, speculate, quartets, swore, protectionist, freud, headstone, stephen,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2407 0.6351 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2272 0.6286 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2125 0.6303 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1392 0.6261 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1654 0.6144 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1454 0.6241 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1686 0.5461 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1816 0.4708 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2017 0.4698 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1965 0.4683 sec/batch
# Nearest to over: otherwise, posed, dictators, whisky, evidentiary, doers, toulon, apolitical,
# Nearest to this: without, injective, variable, divisible, grammarians, weert, parsed, antients,
# Nearest to see: learning, rsfsr, corum, souk, dictionary, vandal, dagger, soho,
# Nearest to after: vulnerable, testimonials, medal, playfair, skyway, kills, uncomfortable, fearful,
# Nearest to an: stol, divest, caveat, fruiting, arterial, steered, genealogical, varitek,
# Nearest to which: narrows, as, midgard, nitrox, scratches, beholder, appetites, ailes,
# Nearest to been: hobsbawm, extraordinarily, erythromycin, encirclement, horrible, glorifying, existed, paps,
# Nearest to used: photocopies, beetles, lexicon, ingots, nutrition, affricate, adaptable, computer,
# Nearest to heavy: smash, wheeled, attenuated, ailes, warrior, cannae, freshmen, types,
# Nearest to nobel: economist, laureate, theory, substantiate, pacifist, hales, randi, beccaria,
# Nearest to award: awarded, fiction, nbc, awards, wong, pitched, fuerzas, movies,
# Nearest to magazine: promotional, film, addams, jawaharlal, belatedly, com, billingsley, paged,
# Nearest to construction: december, letterboxing, roasting, monopolistic, explicated, subscribe, cab, unsustainable,
# Nearest to experience: numeration, combines, denaturation, fibrous, dual, careless, as, mores,
# Nearest to hit: rap, slim, darryl, mike, disappointment, aces, maldivians, charts,
# Nearest to marriage: baal, speculate, quartets, swore, protectionist, warrants, freud, eternal,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1957 0.4759 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2097 0.4690 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1946 0.4782 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1569 0.4679 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1849 0.4659 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1821 0.4669 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1855 0.4709 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1798 0.6142 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1561 0.5570 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1979 0.6160 sec/batch
# Nearest to over: otherwise, posed, omar, dictators, barghouti, male, evidentiary, toulon,
# Nearest to this: without, divisible, variable, injective, parsed, weert, sapphic, approx,
# Nearest to see: learning, dictionary, vandal, corum, rsfsr, souk, hofstadter, periodicals,
# Nearest to after: vulnerable, testimonials, medal, skyway, kills, spacewalk, fearful, playfair,
# Nearest to an: divest, stol, caveat, arterial, fruiting, genealogical, varitek, steered,
# Nearest to which: athaliah, midgard, narrows, scratches, beholder, ailes, as, master,
# Nearest to been: hobsbawm, extraordinarily, encirclement, existed, paps, repairs, horrible, glorifying,
# Nearest to used: photocopies, beetles, lexicon, ingots, nutrition, replete, cycled, computer,
# Nearest to heavy: smash, attenuated, wheeled, ailes, warrior, cannae, freshmen, rougher,
# Nearest to nobel: economist, laureate, theory, pacifist, karl, substantiate, randi, beccaria,
# Nearest to award: awarded, fiction, awards, nbc, wong, fuerzas, pitched, jr,
# Nearest to magazine: promotional, addams, film, com, yahoo, billingsley, encyclopedias, jawaharlal,
# Nearest to construction: roasting, explicated, letterboxing, cab, subscribe, monopolistic, december, vip,
# Nearest to experience: numeration, combines, denaturation, as, careless, ncaa, dual, fibrous,
# Nearest to hit: slim, rap, disappointment, mike, darryl, maldivians, aces, upbeat,
# Nearest to marriage: baal, speculate, quartets, protectionist, warrants, freud, headstone, swore,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2033 0.5626 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1535 0.5530 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1751 0.5488 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1588 0.5599 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1148 0.5525 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1402 0.5461 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1744 0.5480 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1154 0.5533 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1911 0.5689 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2062 0.6544 sec/batch
# Nearest to over: posed, otherwise, dictators, omar, barghouti, apolitical, whisky, evidentiary,
# Nearest to this: without, weert, divisible, antients, kokomo, fascination, yomi, disguises,
# Nearest to see: learning, vandal, souk, rsfsr, dictionary, brandeis, corum, hofstadter,
# Nearest to after: testimonials, vulnerable, spacewalk, nihonshoki, medal, skyway, fearful, playfair,
# Nearest to an: divest, varitek, caveat, bast, genealogical, heroin, attention, stol,
# Nearest to which: as, scratches, midgard, narrows, marxism, master, ailes, athaliah,
# Nearest to been: hobsbawm, encirclement, paps, existed, extraordinarily, horrible, gillmor, mocks,
# Nearest to used: photocopies, beetles, lexicon, unicode, replete, ingots, cycled, users,
# Nearest to heavy: smash, cannae, attenuated, warrior, ailes, wheeled, wilhelmshaven, unskilled,
# Nearest to nobel: economist, laureate, pacifist, theory, karl, substantiate, beccaria, author,
# Nearest to award: awarded, fiction, awards, nbc, best, fuerzas, nomination, screenplay,
# Nearest to magazine: promotional, addams, film, jawaharlal, com, billingsley, yahoo, encyclopedias,
# Nearest to construction: letterboxing, monopolistic, airshow, roasting, vip, cab, explicated, refining,
# Nearest to experience: numeration, combines, denaturation, as, ncaa, careless, expos, fibrous,
# Nearest to hit: rap, slim, mike, darryl, disappointment, aces, maldivians, mcg,
# Nearest to marriage: baal, speculate, freud, quartets, warrants, protectionist, swore, headstone,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2159 0.5903 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1465 0.5592 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1563 0.5901 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1406 0.5659 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0388 0.6055 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1390 0.6472 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1594 0.6271 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1381 0.7550 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1915 0.1998 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1238 0.7124 sec/batch
# Nearest to over: otherwise, posed, dictators, omar, male, doers, apolitical, whisky,
# Nearest to this: without, divisible, weert, antients, watchful, parsed, yomi, variable,
# Nearest to see: learning, vandal, rsfsr, corum, dictionary, souk, brandeis, caldera,
# Nearest to after: vulnerable, testimonials, medal, spacewalk, skyway, nihonshoki, fearful, playfair,
# Nearest to an: divest, caveat, stol, genealogical, arterial, heroin, fruiting, varitek,
# Nearest to which: narrows, athaliah, ailes, scratches, beholder, midgard, rivals, master,
# Nearest to been: hobsbawm, existed, encirclement, glorifying, horrible, paps, microprogram, repairs,
# Nearest to used: photocopies, beetles, lexicon, ingots, users, computer, unicode, cycled,
# Nearest to heavy: smash, cannae, attenuated, wheeled, ailes, wilhelmshaven, warrior, inject,
# Nearest to nobel: economist, laureate, pacifist, karl, theory, beccaria, substantiate, randi,
# Nearest to award: awarded, awards, fiction, nbc, best, nomination, screenplay, nominated,
# Nearest to magazine: promotional, addams, film, com, jawaharlal, yahoo, billingsley, paged,
# Nearest to construction: monopolistic, roasting, refining, vip, letterboxing, explicated, airshow, unsustainable,
# Nearest to experience: numeration, combines, denaturation, careless, ncaa, exhibitionism, as, fibrous,
# Nearest to hit: slim, rap, disappointment, darryl, mike, aces, maldivians, mcg,
# Nearest to marriage: baal, speculate, warrants, freud, protectionist, quartets, swore, marriages,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0736 0.6492 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0875 0.6563 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0819 0.5523 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0716 0.7554 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0768 0.6574 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0428 0.6920 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0772 0.7048 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0747 0.7130 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1106 0.7021 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0033 0.7189 sec/batch
# Nearest to over: otherwise, posed, dictators, omar, male, makeshift, apolitical, reeves,
# Nearest to this: without, weert, parsed, divisible, variable, antients, yomi, injective,
# Nearest to see: vandal, learning, rsfsr, corum, brandeis, dictionary, dagger, hofstadter,
# Nearest to after: vulnerable, testimonials, medal, spacewalk, kills, nihonshoki, fearful, uncomfortable,
# Nearest to an: divest, genealogical, stol, varitek, caveat, bast, arterial, heroin,
# Nearest to which: assam, as, narrows, scratches, ailes, midgard, dredging, appetites,
# Nearest to been: hobsbawm, repairs, encirclement, extraordinarily, golf, existed, erythromycin, painstaking,
# Nearest to used: photocopies, beetles, ingots, lexicon, computer, nutrition, replete, cycled,
# Nearest to heavy: smash, cannae, wilhelmshaven, attenuated, wheeled, ailes, types, inject,
# Nearest to nobel: economist, laureate, pacifist, karl, theory, beccaria, substantiate, randi,
# Nearest to award: awarded, awards, fiction, nbc, best, nomination, nominated, screenplay,
# Nearest to magazine: promotional, addams, com, film, jawaharlal, yahoo, paged, billingsley,
# Nearest to construction: monopolistic, vip, explicated, roasting, letterboxing, refining, gneisenau, unsustainable,
# Nearest to experience: numeration, denaturation, combines, careless, exhibitionism, ncaa, susumu, as,
# Nearest to hit: slim, rap, disappointment, mike, darryl, aces, upbeat, maldivians,
# Nearest to marriage: baal, freud, speculate, protectionist, marriages, warrants, quartets, swore,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0257 0.7013 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0321 0.7290 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0141 0.7006 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0728 0.7251 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0752 0.7065 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0623 0.7110 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0662 0.7293 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0897 0.7156 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0457 0.7173 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0281 0.8302 sec/batch
# Nearest to over: otherwise, posed, doers, dictators, male, posturing, apolitical, omar,
# Nearest to this: without, variable, divisible, yomi, datasets, parsed, approx, injective,
# Nearest to see: learning, dictionary, hofstadter, vandal, corum, brandeis, sinauer, dagger,
# Nearest to after: vulnerable, testimonials, medal, nihonshoki, skyway, playfair, kills, uncomfortable,
# Nearest to an: divest, stol, varitek, caveat, genealogical, a, metrizable, arterial,
# Nearest to which: antisymmetry, tubes, as, scratches, assam, bgcolor, an, system,
# Nearest to been: existed, hobsbawm, paps, pottery, repairs, erythromycin, horrible, account,
# Nearest to used: photocopies, beetles, lexicon, ingots, replete, cycled, deliberation, icq,
# Nearest to heavy: smash, attenuated, inject, cannae, wilhelmshaven, wheeled, ailes, ores,
# Nearest to nobel: economist, laureate, pacifist, karl, theory, beccaria, substantiate, pyrite,
# Nearest to award: awarded, awards, fiction, nbc, best, nomination, nominated, cop,
# Nearest to magazine: addams, promotional, com, comics, jawaharlal, yahoo, encyclopedias, film,
# Nearest to construction: explicated, monopolistic, vip, letterboxing, airshow, clitoridotomy, rterbuch, gneisenau,
# Nearest to experience: numeration, careless, combines, exhibitionism, denaturation, ncaa, provide, symbolised,
# Nearest to hit: rap, disappointment, slim, mike, upbeat, darryl, aces, rotates,
# Nearest to marriage: baal, marriages, protectionist, remarried, warrants, speculate, freud, aunt,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0862 0.4815 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0724 0.4724 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0833 0.4752 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0312 0.4758 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0536 0.4736 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0538 0.4742 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0768 0.4786 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0624 0.4742 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0762 0.5417 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0748 0.7065 sec/batch
# Nearest to over: otherwise, posed, dictators, omar, barghouti, posturing, apolitical, afghan,
# Nearest to this: without, divisible, variable, weert, antients, yomi, parsed, approx,
# Nearest to see: vandal, brandeis, learning, dictionary, dagger, corum, hofstadter, rsfsr,
# Nearest to after: testimonials, vulnerable, nihonshoki, medal, bishoprics, skyway, playfair, jeremiah,
# Nearest to an: divest, varitek, genealogical, stol, bast, caveat, rescued, baffle,
# Nearest to which: assam, midgard, hinduism, was, ailes, rivals, as, consecutively,
# Nearest to been: hobsbawm, existed, horrible, gillmor, mocks, glorifying, golf, paps,
# Nearest to used: photocopies, beetles, lexicon, replete, ingots, relish, affricate, unicode,
# Nearest to heavy: smash, inject, cannae, attenuated, ores, wilhelmshaven, ailes, shapes,
# Nearest to nobel: economist, laureate, pacifist, karl, beccaria, substantiate, obp, pyrite,
# Nearest to award: awarded, awards, fiction, best, nbc, nomination, nominated, screenplay,
# Nearest to magazine: promotional, addams, com, encyclopedias, comics, paged, yahoo, guide,
# Nearest to construction: explicated, monopolistic, letterboxing, unsustainable, refining, airshow, clitoridotomy, vip,
# Nearest to experience: numeration, careless, combines, denaturation, exhibitionism, ncaa, expos, provide,
# Nearest to hit: disappointment, rap, slim, mike, darryl, upbeat, aces, mcg,
# Nearest to marriage: protectionist, remarried, marriages, warrants, her, freud, baal, speculate,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0616 0.7259 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0258 0.4877 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0395 0.4701 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0573 0.4759 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0934 0.4772 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1318 0.4734 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1397 0.4702 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0478 0.4811 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0545 0.4686 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0427 0.4669 sec/batch
# Nearest to over: otherwise, posed, barghouti, dictators, afghan, male, omar, posturing,
# Nearest to this: without, variable, datasets, parsed, divisible, yomi, antients, approx,
# Nearest to see: vandal, brandeis, patricia, corum, dagger, rsfsr, hofstadter, dictionary,
# Nearest to after: testimonials, vulnerable, medal, skyway, nihonshoki, playfair, bishoprics, spacewalk,
# Nearest to an: divest, stol, genealogical, varitek, caveat, bast, baffle, heroin,
# Nearest to which: midgard, antisymmetry, beholder, hinduism, ailes, appetites, motivation, its,
# Nearest to been: hobsbawm, horrible, existed, mocks, encirclement, gillmor, golf, glorifying,
# Nearest to used: photocopies, beetles, lexicon, replete, relish, deliberation, ingots, nutrition,
# Nearest to heavy: smash, inject, attenuated, cannae, wilhelmshaven, neutralizing, ores, ailes,
# Nearest to nobel: economist, laureate, pacifist, prize, karl, beccaria, pyrite, obp,
# Nearest to award: awarded, awards, fiction, best, nomination, nbc, screenplay, nominated,
# Nearest to magazine: addams, promotional, jawaharlal, com, encyclopedias, comics, paged, creighton,
# Nearest to construction: explicated, monopolistic, refining, chanter, airshow, gneisenau, vip, huf,
# Nearest to experience: numeration, combines, denaturation, careless, exhibitionism, ncaa, expos, quartic,
# Nearest to hit: mike, disappointment, rap, darryl, slim, aces, mcg, upbeat,
# Nearest to marriage: marriages, protectionist, remarried, aunt, headstone, freud, warrants, baal,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9609 0.4746 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0471 0.4722 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0178 0.4730 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0550 0.5464 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0992 0.7283 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0234 0.7258 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0387 0.6463 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9658 0.7283 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0073 0.6251 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9732 0.6144 sec/batch
# Nearest to over: otherwise, posed, makeshift, barghouti, dictators, male, posturing, omar,
# Nearest to this: without, divisible, antients, parsed, pythagorean, datasets, variable, approx,
# Nearest to see: brandeis, corum, vandal, dictionary, hofstadter, sinauer, dagger, patricia,
# Nearest to after: testimonials, vulnerable, skyway, nihonshoki, medal, jeremiah, bishoprics, playfair,
# Nearest to an: divest, genealogical, a, stol, pragmatically, exists, caveat, baffle,
# Nearest to which: hinduism, midgard, appetites, was, assam, ailes, bucharest, as,
# Nearest to been: horrible, hobsbawm, existed, mocks, pottery, larva, painstaking, erythromycin,
# Nearest to used: photocopies, beetles, lexicon, ingots, nutrition, replete, deliberation, relish,
# Nearest to heavy: smash, attenuated, inject, cannae, ores, shapes, neutralizing, wilhelmshaven,
# Nearest to nobel: economist, laureate, pacifist, prize, beccaria, karl, recipient, author,
# Nearest to award: awarded, awards, fiction, best, nomination, nominated, screenplay, nbc,
# Nearest to magazine: addams, promotional, jawaharlal, paged, comics, com, encyclopedias, creighton,
# Nearest to construction: monopolistic, explicated, refining, gneisenau, airshow, redeveloped, huf, unsustainable,
# Nearest to experience: numeration, careless, denaturation, combines, exhibitionism, provide, ncaa, spiritual,
# Nearest to hit: disappointment, rap, mike, slim, mcg, aces, darryl, upbeat,
# Nearest to marriage: marriages, remarried, protectionist, aunt, freud, warrants, headstone, her,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9875 0.5498 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9570 0.5478 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9880 0.5421 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0190 0.5581 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0340 0.6061 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9805 0.5747 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9315 0.6183 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9988 0.6351 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9411 0.5927 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0005 0.5897 sec/batch
# Nearest to over: otherwise, posed, makeshift, four, years, male, dictators, posturing,
# Nearest to this: without, parsed, variable, divisible, injective, yomi, datasets, monists,
# Nearest to see: corum, brandeis, dictionary, sinauer, patricia, dagger, parabola, hofstadter,
# Nearest to after: testimonials, vulnerable, skyway, medal, playfair, bishoprics, forever, uncomfortable,
# Nearest to an: divest, a, exists, stol, varitek, which, baffle, genealogical,
# Nearest to which: its, as, usually, assam, antisymmetry, an, system, ailes,
# Nearest to been: hobsbawm, larva, pottery, existed, horrible, mocks, statistic, account,
# Nearest to used: beetles, photocopies, lexicon, ingots, nutrition, replete, shapes, use,
# Nearest to heavy: attenuated, smash, inject, cannae, wilhelmshaven, ores, warrior, shapes,
# Nearest to nobel: economist, laureate, pacifist, beccaria, obp, prize, karl, pyrite,
# Nearest to award: awarded, awards, fiction, nominated, nbc, nomination, best, screenplay,
# Nearest to magazine: addams, comics, jawaharlal, promotional, encyclopedias, paged, com, creighton,
# Nearest to construction: redeveloped, gneisenau, monopolistic, explicated, opened, vip, airshow, unsustainable,
# Nearest to experience: numeration, combines, denaturation, careless, exhibitionism, ncaa, laughter, provide,
# Nearest to hit: disappointment, rap, mike, aces, rotates, slim, upbeat, mcg,
# Nearest to marriage: marriages, remarried, aunt, protectionist, freud, her, headstone, striving,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9998 0.6241 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9654 0.6828 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9824 0.6466 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0218 0.6723 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0349 0.6148 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9588 0.6957 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9760 0.6003 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9970 0.6018 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0229 0.6236 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9909 0.6451 sec/batch
# Nearest to over: otherwise, posed, posturing, dictators, barghouti, factoring, years, male,
# Nearest to this: without, variable, divisible, parsed, datasets, plies, canonically, injective,
# Nearest to see: brandeis, corum, hofstadter, dictionary, vandal, sinauer, patricia, rsfsr,
# Nearest to after: testimonials, vulnerable, skyway, medal, bishoprics, late, playfair, gardena,
# Nearest to an: a, divest, baffle, varitek, solely, genealogical, attention, stol,
# Nearest to which: its, hinduism, francione, as, assam, was, motivation, rivals,
# Nearest to been: hobsbawm, existed, mocks, larva, horrible, gillmor, statistic, pottery,
# Nearest to used: photocopies, beetles, lexicon, replete, users, nutrition, use, ingots,
# Nearest to heavy: inject, smash, attenuated, ores, cannae, wilhelmshaven, shapes, neutralizing,
# Nearest to nobel: economist, laureate, pacifist, prize, beccaria, obp, karl, recipient,
# Nearest to award: awarded, awards, best, fiction, nominated, nomination, nbc, screenplay,
# Nearest to magazine: addams, comics, encyclopedias, com, promotional, jawaharlal, creighton, paged,
# Nearest to construction: explicated, redeveloped, monopolistic, gneisenau, opened, chanter, np, airshow,
# Nearest to experience: careless, numeration, exhibitionism, denaturation, combines, provide, ncaa, laughter,
# Nearest to hit: disappointment, rap, upbeat, slim, exceeded, mcg, mike, aces,
# Nearest to marriage: marriages, remarried, aunt, her, protectionist, freud, headstone, divorce,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0057 0.6760 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9945 0.6811 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9736 0.5144 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0135 0.5107 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0115 0.5097 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0050 0.5102 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9816 0.5097 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9451 0.5137 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9791 0.5411 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0126 0.5497 sec/batch
# Nearest to over: otherwise, posed, years, barghouti, afghan, posturing, on, dictators,
# Nearest to this: without, variable, canonically, plies, datasets, parsed, weert, grammarians,
# Nearest to see: brandeis, corum, dictionary, vandal, patricia, communications, hofstadter, external,
# Nearest to after: testimonials, bishoprics, skyway, vulnerable, nihonshoki, became, medal, late,
# Nearest to an: a, divest, which, pragmatically, solely, genealogical, baffle, permit,
# Nearest to which: its, an, the, hinduism, be, midgard, as, appetites,
# Nearest to been: hobsbawm, existed, gillmor, horrible, mocks, statistic, golf, larva,
# Nearest to used: photocopies, beetles, lexicon, replete, users, also, use, shapes,
# Nearest to heavy: inject, ores, cannae, smash, attenuated, neutralizing, shapes, wilhelmshaven,
# Nearest to nobel: economist, laureate, pacifist, prize, beccaria, obp, karl, recipient,
# ...
# Nearest to heavy: inject, smash, ores, attenuated, neutralizing, cannae, wilhelmshaven, sternly,
# Nearest to nobel: laureate, prize, economist, pacifist, beccaria, obp, recipient, pharmacologist,
# Nearest to award: awarded, awards, best, nominated, emmy, fiction, nebula, prize,
# Nearest to magazine: addams, gun, encyclopedias, creighton, com, magazines, unannounced, comics,
# Nearest to construction: gneisenau, redeveloped, built, explicated, monopolistic, concrete, airshow, roasting,
# Nearest to experience: careless, provide, exhibitionism, denaturation, combines, ncaa, laughter, quark,
# Nearest to hit: disappointment, upbeat, rotates, exceeded, rap, batted, india, charts,
# Nearest to marriage: marriages, remarried, divorce, protectionist, aunt, her, wedlock, headstone,
# Epoch 7/10 Iteration: 29100 Avg. Training loss: 3.8713 0.6122 sec/batch
# Epoch 7/10 Iteration: 29200 Avg. Training loss: 3.8464 0.5967 sec/batch
# Epoch 7/10 Iteration: 29300 Avg. Training loss: 3.8871 0.6269 sec/batch
# Epoch 7/10 Iteration: 29400 Avg. Training loss: 3.9147 0.6088 sec/batch
# Epoch 7/10 Iteration: 29500 Avg. Training loss: 3.8981 0.6239 sec/batch
# Epoch 7/10 Iteration: 29600 Avg. Training loss: 3.8803 0.5979 sec/batch
# Epoch 7/10 Iteration: 29700 Avg. Training loss: 3.9401 0.5966 sec/batch
# Epoch 7/10 Iteration: 29800 Avg. Training loss: 3.9098 0.5988 sec/batch
# Epoch 7/10 Iteration: 29900 Avg. Training loss: 3.8907 0.5904 sec/batch
# Epoch 7/10 Iteration: 30000 Avg. Training loss: 3.9183 0.6108 sec/batch
# Nearest to over: otherwise, years, four, female, for, endured, on, suzerainty,
# Nearest to this: without, as, of, plies, is, be, septimius, for,
# Nearest to see: external, brandeis, corum, dagger, article, cartographers, hofstadter, also,
# Nearest to after: testimonials, nihonshoki, postulate, forever, saadia, exiled, became, during,
# Nearest to an: a, which, exists, bast, of, andalus, baffle, varitek,
# Nearest to which: its, the, of, as, an, by, hinduism, subsequent,
# Nearest to been: has, hobsbawm, existed, pottery, oligarchic, gillmor, however, horrible,
# Nearest to used: photocopies, use, beetles, addition, ingots, doctorow, replete, bokm,
# Nearest to heavy: inject, smash, ores, attenuated, cannae, neutralizing, sternly, wilhelmshaven,
# Nearest to nobel: prize, laureate, economist, pacifist, beccaria, obp, caldera, adventurers,
# Nearest to award: awarded, awards, best, nominated, emmy, nebula, outstanding, fiction,
# Nearest to magazine: addams, gun, encyclopedias, comics, creighton, diary, billingsley, unannounced,
# Nearest to construction: redeveloped, gneisenau, built, explicated, concrete, mathematics, clitoridotomy, chanter,
# Nearest to experience: careless, provide, exhibitionism, laughter, ncaa, combines, quark, denaturation,
# Nearest to hit: disappointment, upbeat, charts, rap, rotates, exceeded, batted, gracen,
# Nearest to marriage: marriages, divorce, remarried, protectionist, her, aunt, marry, wedlock,
# Epoch 7/10 Iteration: 30100 Avg. Training loss: 3.8994 0.6058 sec/batch
# Epoch 7/10 Iteration: 30200 Avg. Training loss: 3.9405 0.6003 sec/batch
# Epoch 7/10 Iteration: 30300 Avg. Training loss: 3.8970 0.5964 sec/batch
# Epoch 7/10 Iteration: 30400 Avg. Training loss: 3.9131 0.5963 sec/batch
# Epoch 7/10 Iteration: 30500 Avg. Training loss: 3.8785 0.6035 sec/batch
# Epoch 7/10 Iteration: 30600 Avg. Training loss: 3.9314 0.5933 sec/batch
# Epoch 7/10 Iteration: 30700 Avg. Training loss: 3.9220 0.5961 sec/batch
# Epoch 7/10 Iteration: 30800 Avg. Training loss: 3.9226 0.5915 sec/batch
# Epoch 7/10 Iteration: 30900 Avg. Training loss: 3.9385 0.5948 sec/batch
# Epoch 7/10 Iteration: 31000 Avg. Training loss: 3.8846 0.6093 sec/batch
# Nearest to over: years, otherwise, four, of, on, suzerainty, for, and,
# Nearest to this: of, without, plies, as, canonically, in, exception, septimius,
# Nearest to see: external, article, dagger, brandeis, communications, cartographers, corum, bounce,
# Nearest to after: testimonials, nihonshoki, exiled, postulate, shortly, during, bishoprics, forever,
# Nearest to an: a, which, andalus, exists, bast, the, of, divest,
# Nearest to which: the, its, of, by, as, in, hinduism, an,
# Nearest to been: has, hobsbawm, existed, gillmor, however, lapu, oligarchic, weakens,
# Nearest to used: photocopies, use, addition, beetles, replete, doctorow, ingots, bokm,
# Nearest to heavy: inject, ores, smash, attenuated, neutralizing, cannae, metal, desalination,
# Nearest to nobel: prize, laureate, economist, pacifist, beccaria, obp, awarded, caldera,
# Nearest to award: awarded, awards, best, nominated, emmy, nebula, outstanding, mvp,
# Nearest to magazine: gun, addams, encyclopedias, magazines, creighton, comics, billingsley, globes,
# Nearest to construction: redeveloped, built, gneisenau, concrete, lumber, airshow, agricultural, explicated,
# Nearest to experience: careless, provide, laughter, exhibitionism, ncaa, symbolised, slbms, undress,
# Nearest to hit: disappointment, upbeat, charts, exceeded, rap, maldivians, labels, rotates,
# Nearest to marriage: marriages, divorce, remarried, protectionist, her, headstone, aunt, wedlock,
# Epoch 7/10 Iteration: 31100 Avg. Training loss: 3.8939 0.6061 sec/batch
# Epoch 7/10 Iteration: 31200 Avg. Training loss: 3.9338 0.5945 sec/batch
# Epoch 7/10 Iteration: 31300 Avg. Training loss: 3.8783 0.5993 sec/batch
# Epoch 7/10 Iteration: 31400 Avg. Training loss: 3.9553 0.5964 sec/batch
# Epoch 7/10 Iteration: 31500 Avg. Training loss: 3.9768 0.6090 sec/batch
# Epoch 7/10 Iteration: 31600 Avg. Training loss: 3.9820 0.6061 sec/batch
# Epoch 7/10 Iteration: 31700 Avg. Training loss: 3.9178 0.5946 sec/batch
# Epoch 7/10 Iteration: 31800 Avg. Training loss: 3.8711 0.5920 sec/batch
# Epoch 7/10 Iteration: 31900 Avg. Training loss: 3.9021 0.5941 sec/batch
# Epoch 7/10 Iteration: 32000 Avg. Training loss: 3.7709 0.6140 sec/batch
# Nearest to over: years, four, of, otherwise, female, and, suzerainty, on,
# Nearest to this: without, plies, tremendous, be, naturally, as, of, canonically,
# Nearest to see: external, communications, article, cartographers, dagger, brandeis, marten, corum,
# Nearest to after: testimonials, exiled, during, became, was, nihonshoki, he, shortly,
# Nearest to an: a, which, the, as, andalus, exists, of, bast,
# Nearest to which: the, its, of, by, as, an, a, in,
# Nearest to been: has, hobsbawm, existed, however, gillmor, oligarchic, lapu, larva,
# Nearest to used: use, photocopies, beetles, as, addition, ingots, doctorow, bokm,
# Nearest to heavy: inject, ores, smash, neutralizing, desalination, metal, attenuated, romero,
# Nearest to nobel: prize, laureate, economist, pacifist, beccaria, obp, awarded, caldera,
# Nearest to award: awarded, awards, best, nebula, emmy, nominated, outstanding, prize,
# Nearest to magazine: gun, addams, encyclopedias, magazines, billingsley, creighton, comics, com,
# Nearest to construction: redeveloped, gneisenau, built, explicated, agricultural, concrete, huf, minims,
# Nearest to experience: careless, provide, laughter, ncaa, exhibitionism, combines, quark, symbolised,
# Nearest to hit: disappointment, upbeat, charts, exceeded, rap, maldivians, labels, india,
# Nearest to marriage: marriages, remarried, divorce, protectionist, marry, headstone, wedlock, aunt,
# Epoch 7/10 Iteration: 32100 Avg. Training loss: 3.9198 0.6038 sec/batch
# Epoch 7/10 Iteration: 32200 Avg. Training loss: 3.9186 0.5966 sec/batch
# Epoch 7/10 Iteration: 32300 Avg. Training loss: 3.9119 0.5993 sec/batch
# Epoch 8/10 Iteration: 32400 Avg. Training loss: 3.9492 0.1532 sec/batch
# Epoch 8/10 Iteration: 32500 Avg. Training loss: 3.8927 0.6129 sec/batch
# Epoch 8/10 Iteration: 32600 Avg. Training loss: 3.8705 0.5985 sec/batch
# Epoch 8/10 Iteration: 32700 Avg. Training loss: 3.8875 0.5988 sec/batch
# Epoch 8/10 Iteration: 32800 Avg. Training loss: 3.9165 0.5970 sec/batch
# Epoch 8/10 Iteration: 32900 Avg. Training loss: 3.8407 0.5918 sec/batch
# Epoch 8/10 Iteration: 33000 Avg. Training loss: 3.9009 0.6150 sec/batch
# Nearest to over: four, otherwise, years, of, on, for, suzerainty, endured,
# Nearest to this: of, without, be, as, in, all, on, which,
# Nearest to see: external, communications, article, also, brandeis, dagger, corum, marten,
# Nearest to after: testimonials, exiled, nihonshoki, became, was, during, wife, named,
# Nearest to an: a, which, of, bast, the, as, exists, andalus,
# Nearest to which: the, of, its, as, by, in, a, was,
# Nearest to been: has, hobsbawm, however, existed, gillmor, pottery, horrible, eakins,
# Nearest to used: also, beetles, use, as, ingots, addition, photocopies, replete,
# Nearest to heavy: inject, smash, ores, neutralizing, attenuated, metal, cannae, romero,
# Nearest to nobel: prize, laureate, economist, pacifist, beccaria, recipient, comedian, obp,
# Nearest to award: awarded, awards, best, emmy, nominated, outstanding, nebula, nominations,
# Nearest to magazine: gun, addams, encyclopedias, billingsley, magazines, comics, globes, creighton,
# Nearest to construction: gneisenau, redeveloped, built, explicated, airshow, phoned, outgrowth, bijective,
# Nearest to experience: careless, provide, laughter, exhibitionism, undress, symbolised, ncaa, combines,
# Nearest to hit: disappointment, upbeat, charts, exceeded, rap, labels, maldivians, rotates,
# Nearest to marriage: marriages, remarried, divorce, protectionist, wedlock, marry, headstone, livia,
# Epoch 8/10 Iteration: 33100 Avg. Training loss: 3.8222 0.6043 sec/batch
# Epoch 8/10 Iteration: 33200 Avg. Training loss: 3.8656 0.5983 sec/batch
# Epoch 8/10 Iteration: 33300 Avg. Training loss: 3.9106 0.6018 sec/batch
# Epoch 8/10 Iteration: 33400 Avg. Training loss: 3.9359 0.5944 sec/batch
# Epoch 8/10 Iteration: 33500 Avg. Training loss: 3.8112 0.6042 sec/batch
# Epoch 8/10 Iteration: 33600 Avg. Training loss: 3.8485 0.6103 sec/batch
# Epoch 8/10 Iteration: 33700 Avg. Training loss: 3.8712 0.5948 sec/batch
# Epoch 8/10 Iteration: 33800 Avg. Training loss: 3.7860 0.5927 sec/batch
# Epoch 8/10 Iteration: 33900 Avg. Training loss: 3.8790 0.5940 sec/batch
# Epoch 8/10 Iteration: 34000 Avg. Training loss: 3.8716 0.6086 sec/batch
# Nearest to over: four, years, otherwise, for, of, on, seven, in,
# Nearest to this: of, without, as, be, is, all, on, for,
# Nearest to see: external, also, article, brandeis, list, communications, an, dagger,
# Nearest to after: testimonials, forever, nihonshoki, exiled, named, wife, during, shortly,
# Nearest to an: a, which, of, as, the, exists, bast, electropositive,
# Nearest to which: of, its, the, a, as, in, by, an,
# Nearest to been: has, however, hobsbawm, existed, oligarchic, pottery, weakens, gillmor,
# Nearest to used: also, beetles, as, use, addition, ingots, refers, replete,
# Nearest to heavy: inject, smash, ores, neutralizing, attenuated, metal, wilhelmshaven, cannae,
# Nearest to nobel: prize, laureate, economist, pacifist, beccaria, downloads, obp, winner,
# Nearest to award: awarded, awards, best, outstanding, emmy, nominated, nominations, prize,
# Nearest to magazine: gun, addams, encyclopedias, magazines, billingsley, comics, creighton, globes,
# Nearest to construction: gneisenau, built, redeveloped, explicated, phoned, underneath, airshow, minims,
# Nearest to experience: careless, ncaa, exhibitionism, provide, laughter, quark, combines, denaturation,
# Nearest to hit: disappointment, hits, upbeat, charts, batted, worst, exceeded, pace,
# Nearest to marriage: marriages, divorce, remarried, marry, protectionist, wedlock, cdpd, livia,
# Epoch 8/10 Iteration: 34100 Avg. Training loss: 3.8595 0.6064 sec/batch
# Epoch 8/10 Iteration: 34200 Avg. Training loss: 3.8853 0.6019 sec/batch
# Epoch 8/10 Iteration: 34300 Avg. Training loss: 3.9393 0.6016 sec/batch
# Epoch 8/10 Iteration: 34400 Avg. Training loss: 3.8675 0.6018 sec/batch
# Epoch 8/10 Iteration: 34500 Avg. Training loss: 3.8693 0.6111 sec/batch
# Epoch 8/10 Iteration: 34600 Avg. Training loss: 3.8840 0.6048 sec/batch
# Epoch 8/10 Iteration: 34700 Avg. Training loss: 3.9140 0.5996 sec/batch
# Epoch 8/10 Iteration: 34800 Avg. Training loss: 3.9050 0.6026 sec/batch
# Epoch 8/10 Iteration: 34900 Avg. Training loss: 3.8563 0.5938 sec/batch
# Epoch 8/10 Iteration: 35000 Avg. Training loss: 3.8926 0.6194 sec/batch
# Nearest to over: four, for, years, otherwise, on, in, seven, of,
# Nearest to this: of, as, be, for, without, in, only, all,
# Nearest to see: external, article, also, communications, list, an, brandeis, cartographers,
# Nearest to after: testimonials, during, nihonshoki, forever, shortly, wife, named, exiled,
# Nearest to an: a, of, which, the, as, from, for, in,
# Nearest to which: of, the, by, a, in, as, its, an,
# Nearest to been: has, however, hobsbawm, gillmor, existed, oligarchic, weakens, as,
# Nearest to used: as, use, addition, also, beetles, photocopies, bokm, the,
# Nearest to heavy: inject, ores, smash, attenuated, neutralizing, storch, metal, romero,
# Nearest to nobel: prize, laureate, economist, pacifist, beccaria, recipient, downloads, peace,
# Nearest to award: awarded, awards, best, outstanding, emmy, nominated, nominations, nebula,
# Nearest to magazine: gun, addams, magazines, encyclopedias, com, creighton, comics, billingsley,
# Nearest to construction: redeveloped, gneisenau, built, explicated, outgrowth, phoned, airshow, bijective,
# Nearest to experience: careless, ncaa, laughter, exhibitionism, provide, symbolised, expos, quark,
# Nearest to hit: disappointment, upbeat, charts, hits, labels, deuce, maldivians, worst,
# Nearest to marriage: marriages, divorce, remarried, protectionist, marry, cdpd, wedlock, aunt,
# Epoch 8/10 Iteration: 35100 Avg. Training loss: 3.8963 0.6116 sec/batch
# Epoch 8/10 Iteration: 35200 Avg. Training loss: 3.9004 0.5940 sec/batch
# Epoch 8/10 Iteration: 35300 Avg. Training loss: 3.8872 0.6066 sec/batch
# Epoch 8/10 Iteration: 35400 Avg. Training loss: 3.9117 0.5997 sec/batch
# Epoch 8/10 Iteration: 35500 Avg. Training loss: 3.8735 0.6414 sec/batch
# Epoch 8/10 Iteration: 35600 Avg. Training loss: 3.8737 0.6204 sec/batch
# Epoch 8/10 Iteration: 35700 Avg. Training loss: 3.8485 0.5499 sec/batch
# Epoch 8/10 Iteration: 35800 Avg. Training loss: 3.8815 0.5981 sec/batch
# Epoch 8/10 Iteration: 35900 Avg. Training loss: 3.8980 0.6184 sec/batch
# Epoch 8/10 Iteration: 36000 Avg. Training loss: 3.9025 0.5754 sec/batch
# Nearest to over: years, four, of, for, otherwise, on, and, in,
# Nearest to this: of, on, without, as, in, exception, all, be,
# Nearest to see: external, article, also, list, communications, marten, dagger, brandeis,
# Nearest to after: testimonials, named, during, wife, exiled, nihonshoki, in, forever,
# Nearest to an: a, of, which, the, from, bast, as, varitek,
# Nearest to which: the, of, its, in, a, by, hinduism, as,
# Nearest to been: has, however, hobsbawm, existed, weakens, gillmor, oligarchic, negotiating,
# Nearest to used: addition, also, photocopies, beetles, use, as, refers, bokm,
# Nearest to heavy: inject, metal, ores, smash, neutralizing, storch, desalination, romero,
# Nearest to nobel: prize, laureate, economist, pacifist, recipient, comedian, beccaria, obp,
# Nearest to award: awarded, awards, best, emmy, outstanding, prize, nebula, nominated,
# Nearest to magazine: gun, addams, magazines, creighton, published, encyclopedias, globes, billingsley,
# Nearest to construction: gneisenau, redeveloped, built, explicated, airshow, barges, outgrowth, phoned,
# Nearest to experience: careless, laughter, ncaa, symbolised, exhibitionism, expos, provide, quark,
# Nearest to hit: hits, upbeat, disappointment, charts, career, petrosian, labels, deuce,
# Nearest to marriage: marriages, divorce, remarried, marry, wedlock, protectionist, cdpd, headstone,
# Epoch 8/10 Iteration: 36100 Avg. Training loss: 3.9518 0.6076 sec/batch
# Epoch 8/10 Iteration: 36200 Avg. Training loss: 3.9387 0.5900 sec/batch
# Epoch 8/10 Iteration: 36300 Avg. Training loss: 3.8731 0.5989 sec/batch
# Epoch 8/10 Iteration: 36400 Avg. Training loss: 3.8563 0.7494 sec/batch
# Epoch 8/10 Iteration: 36500 Avg. Training loss: 3.8849 1.4177 sec/batch
# Epoch 8/10 Iteration: 36600 Avg. Training loss: 3.8040 1.4596 sec/batch
# Epoch 8/10 Iteration: 36700 Avg. Training loss: 3.8748 1.5211 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
